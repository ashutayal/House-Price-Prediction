# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2 , f_classif
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import SGDRegressor
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.svm import SVR
from sklearn.neural_network import MLPRegressor

# %%
path = os.path.join(os.getcwd(), 'downloads')
test = pd.read_csv(os.path.join(path, 'test.csv'))
train = pd.read_csv(os.path.join(path, 'train.csv'))

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
# Test Train split and define target and predictors

# %%
train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
data = pd.concat([train, test], axis = 0, sort = False)

# %%
# Looking at missing values

null = pd.DataFrame({'Null Values' : data.isna().sum().sort_values(ascending=False), 
                     'Percentage Null Values' : (data.isna().sum().sort_values(ascending=False)) / (data.shape[0]) * (100)})

# %%
null
# Out:
#                Null Values  Percentage Null Values
# PoolQC                2909               99.657417
# MiscFeature           2814               96.402878
# Alley                 2721               93.216855
# Fence                 2348               80.438506
# SalePrice             1459               49.982871
# ...                    ...                     ...
# CentralAir               0                0.000000
# SaleCondition            0                0.000000
# Heating                  0                0.000000
# Foundation               0                0.000000
# Id                       0                0.000000
#
# [81 rows x 2 columns]

# %% [markdown]
# From this, I see that PoolQC, MiscFeature and Alley have >90% missing values - I drop them.

# %%
data.drop(["PoolQC","MiscFeature","Alley"],axis=1,inplace=True)

# %%
data = data.copy()

# %%
# Imputation function


def imputation(feature):
    random_sample=data[feature].dropna().sample(data[feature].isnull().sum(), replace = True)               
    random_sample.index=data[data[feature].isnull()].index
    data.loc[data[feature].isnull(),feature]=random_sample
# this takes a random sample from the data and uses this to replace missing vals for each feature

for col in data:
    imputation(col)

# %%
new_null = pd.DataFrame({'Null Values' : data.isna().sum().sort_values(ascending=False), 
                     'Percentage Null Values' : (data.isna().sum().sort_values(ascending=False)) / (data.shape[0]) * (100)})

# %%
new_null # sanity check for imputation
# Out:
#               Null Values  Percentage Null Values
# SalePrice               0                     0.0
# Foundation              0                     0.0
# RoofMatl                0                     0.0
# Exterior1st             0                     0.0
# Exterior2nd             0                     0.0
# ...                   ...                     ...
# KitchenQual             0                     0.0
# TotRmsAbvGrd            0                     0.0
# Functional              0                     0.0
# Fireplaces              0                     0.0
# Id                      0                     0.0
#
# [78 rows x 2 columns]

# %%
# Let's look at the correlation heatmap to get a better understanding of the features
plt.rcParams['figure.figsize'] = (30, 15)
corr_df = data.corr()
sns.heatmap(corr_df,annot=True)

# %%
def make_kdeplot(feature) : 
    plt.rcParams['figure.figsize'] = (10, 10)
    sns.kdeplot(data[feature], shade=True)

# %%
make_kdeplot('SalePrice')

# %% [markdown]
# Sale prices seem to follow a normal distribution with a left skew (long right tail)

# %%
data = pd.get_dummies(data) # converts categorical vars to dummy

y = data.SalePrice
X = data.drop('SalePrice', axis = 1)
features = X.columns

# %%
# Test train split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1, shuffle=True)

# %%
y_test
# Out:
# 473    440000.0
# 641    160000.0
# 243    235000.0
# 303    149900.0
# 664    423000.0
#          ...
# 713    129000.0
# 101    124900.0
# 198    151500.0
# 821    207500.0
# 913    145000.0
# Name: SalePrice, Length: 584, dtype: float64

# %%
def predict(selected_model):
    model=selected_model.fit(X_train,y_train)
    print('Training score : {}'.format(model.score(X_train,y_train)))
    y_prediction=model.predict(X_test)
    print('\n')
    r2_score=metrics.r2_score(y_test,y_prediction) # r squared
    print('r2 score: {}'.format(r2_score))
    print('MAE:',metrics.mean_absolute_error(y_test,y_prediction))
    print('MSE:',metrics.mean_squared_error(y_test,y_prediction))
    print('RMSE:',np.sqrt(metrics.mean_squared_error(y_test,y_prediction)))
    sns.distplot(y_test-y_prediction)

# %%
# Linear Regression
predict(LinearRegression())
# Out:
# Training score : 0.3202351629276954
#
#
# r2 score: 0.14275660444179072
# MAE: 53240.4291436983
# MSE: 5852411435.6857605
# RMSE: 76501.05512792461

# %%
# Random Forest
predict(RandomForestRegressor(ccp_alpha=0.1,n_estimators=50, max_depth = 80))
# Out:
# Training score : 0.9125150242465703
#
#
# r2 score: 0.42855336203998007
# MAE: 39922.92845319634
# MSE: 3901273379.544294
# RMSE: 62460.1743476937

# %%
# Gradient Boosting
predict(GradientBoostingRegressor(alpha=.9 , n_estimators=12,learning_rate=0.5, max_depth=12))
# Out:
# Training score : 0.9958280519863842
#
#
# r2 score: 0.3058436424022448
# MAE: 44461.21793018897
# MSE: 4739014177.78053
# RMSE: 68840.49809364056

# %%
predict(Lasso(max_iter=200,alpha=2))
# Out:
# /Users/ashutayal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4492992108536.741, tolerance: 1314825680.4887116
#   positive)
# Training score : 0.31876516144181344
#
#
# r2 score: 0.15411385598260552
# MAE: 52846.05055239177
# MSE: 5774875336.673715
# RMSE: 75992.60053895849

# %%
predict(Ridge(solver='auto',alpha=0.5,  max_iter=12))
# Out:
# Training score : 0.31778548748063606
#
#
# r2 score: 0.1593883362675117
# MAE: 52774.535725883194
# MSE: 5738866393.476685
# RMSE: 75755.30604173338

# %%
predict(DecisionTreeRegressor(max_depth=25,random_state=1))
# Out:
# Training score : 0.9837999131059756
#
#
# r2 score: 0.11475042146365055
# MAE: 51243.79562929451
# MSE: 6043609998.871478
# RMSE: 77740.6585955604

# %% [markdown]
# Looks like Decision Trees help us get an accuracy of 99.5%!
#
# This is what I will use to predict prices.

# %%
test.shape
# Out:
# (1460, 78)

# %%
test = pd.read_csv(os.path.join(path, 'test.csv'))
train = pd.read_csv(os.path.join(path, 'train.csv'))
data = pd.concat([train, test], axis = 0, sort = False)

data.drop(["PoolQC","MiscFeature","Alley"],axis=1,inplace=True)
data = data.copy()

for col in data:
    imputation(col)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=1, shuffle=False)

# %%
selected_model = DecisionTreeRegressor(max_depth=25,random_state=1)
model=selected_model.fit(X_train,y_train)
y_prediction=model.predict(X_test)

# %%
output = pd.DataFrame({"Id":X_test['Id'], "SalePrice": y_prediction})
output.set_index('Id')
# Out:
#       SalePrice
# Id
# 1460   170000.0
# 1461   127500.0
# 1462   145000.0
# 1463   193000.0
# 1464   187500.0
# ...         ...
# 2915    81000.0
# 2916    83000.0
# 2917   145000.0
# 2918    93500.0
# 2919   222000.0
#
# [1460 rows x 1 columns]

# %%
output.iloc[1:,:].to_csv(os.path.join(path, 'submission.csv'))
